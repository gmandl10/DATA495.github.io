# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
master = pd.read_csv("depression_table.csv").set_index("SEQN")
master = pd.DataFrame(master.loc[:, "DepressionScore"])
master.dropna().shape[0]
# Out:
# 4836

# %%
# Blood lead and Blood Cadmium
DS0102 = pd.read_csv("DS0102/25504-0102-Data.tsv", sep = "\t").set_index("SEQN")
columns = DS0102.columns[:np.where(DS0102.columns.values == ("SDDSRVYR"))[0][0]]
master = master.join(DS0102[columns])
master = master.replace(" ", np.NaN )
master.dropna().shape[0]
# Out:
# 4644

# %%
# Complete blood count
DS0103 = pd.read_csv("DS0103/25504-0103-Data.tsv", sep = "\t").set_index("SEQN")
columns = DS0103.columns[:np.where(DS0103.columns.values == ("SDDSRVYR"))[0][0]]
master = master.join(DS0103[columns])
master = master.replace(" ", np.NaN )
master.dropna().shape[0]
# Out:
# 4614

# %%
# C-reactive proteins
DS0104 = pd.read_csv("DS0104/25504-0104-Data.tsv", sep = "\t").set_index("SEQN")
columns = DS0104.columns[:np.where(DS0104.columns.values == ("SDDSRVYR"))[0][0]]
master = master.join(DS0104[columns])
master = master.replace(" ", np.NaN )
master.dropna().shape[0]
# Out:
# 4591

# %%
# Environmental Pesticides
DS0105 = pd.read_csv("DS0105/25504-0105-Data.tsv", sep = "\t").set_index("SEQN")
columns = DS0105.columns[:np.where(DS0105.columns.values == ("SDDSRVYR"))[0][0]]
master = master.join(DS0105[columns])
master = master.replace(" ", np.NaN )
master.dropna().shape[0]
# Out:
# 1447

# %%
master.isnull().sum(axis=0),columns
# Out:
# (DepressionScore       0
#  LBXBCD              192
#  LBDBCDSI            192
#  LBXBPB              192
#  LBDBPBSI            192
#  LBXWBCSI            192
#  LBXLYPCT            211
#  LBXMOPCT            211
#  LBXNEPCT            211
#  LBXEOPCT            211
#  LBXBAPCT            211
#  LBDLYMNO            211
#  LBDMONO             211
#  LBDNENO             211
#  LBDEONO             211
#  LBDBANO             211
#  LBXRBCSI            192
#  LBXHGB              192
#  LBXHCT              192
#  LBXMCVSI            192
#  LBXMCHSI            192
#  LBXMC               192
#  LBXRDW              192
#  LBXPLTSI            192
#  LBXMPSI             192
#  LBXCRP              207
#  WTSB2YR            3279
#  URX14D             3306
#  URD14DLC           3306
#  URXOPP             3306
#  URDOPPLC           3306
#  URXDCB             3306
#  URDDCBLC           3306
#  URX1TB             3306
#  URD1TBLC           3306
#  URX3TB             3306
#  URD3TBLC           3306
#  URXUCR             3297
#  dtype: int64,
#  Index(['WTSB2YR', 'URX14D', 'URD14DLC', 'URXOPP', 'URDOPPLC', 'URXDCB',
#         'URDDCBLC', 'URX1TB', 'URD1TBLC', 'URX3TB', 'URD3TBLC', 'URXUCR'],
#        dtype='object'))

# %% [markdown]
# We lose a lot of observations due to NA's in DS0105 so we will not include the variables from DS0105 in our predictor space

# %%
master.drop(columns, axis = 1, inplace = True)

# %%
# Vitamin D levels
DS0143 = pd.read_csv("DS0143/25504-0143-Data.tsv", sep = "\t").set_index("SEQN")
columns = DS0143.columns[:np.where(DS0143.columns.values == ("SDDSRVYR"))[0][0]]
master = master.join(DS0143[columns])
master = master.replace(" ", np.NaN )
master.dropna().shape[0]
# Out:
# 4147

# %%
master.corr()
# Out:
#                  DepressionScore    LBXBCD  LBDBCDSI    LBXBPB  LBXWBCSI  \
# DepressionScore         1.000000  0.085398  0.085371  0.020539  0.086490
# LBXBCD                  0.085398  1.000000  1.000000  0.182772  0.095528
# LBDBCDSI                0.085371  1.000000  1.000000  0.182733  0.095535
# LBXBPB                  0.020539  0.182772  0.182733  1.000000 -0.049471
# LBXWBCSI                0.086490  0.095528  0.095535 -0.049471  1.000000
# LBDLYMNO                0.024749  0.054873  0.054877 -0.025833  0.621930
# LBDMONO                 0.039166  0.078116  0.078108  0.027674  0.540508
# LBDNENO                 0.093702  0.073871  0.073879 -0.052466  0.810719
# LBDEONO                 0.010203  0.059920  0.059928  0.011694  0.218615
# LBDBANO                 0.031255  0.071271  0.071277 -0.008167  0.331551
# LBXRBCSI               -0.078206  0.054540  0.054570  0.087274 -0.010164
# LBXHGB                 -0.089145  0.140983  0.141013  0.128587 -0.002784
# LBXMCHSI               -0.018395  0.122018  0.122016  0.059423  0.008186
# LBXRDW                  0.118649  0.084576  0.084538  0.115427  0.028080
# LBXPLTSI                0.062647  0.005530  0.005544 -0.101594  0.232801
# LBXMPSI                 0.000353 -0.021277 -0.021291  0.016290  0.032040
# LBXCRP                  0.083865  0.012294  0.012298 -0.014597  0.226939
# LBXVID                 -0.066279 -0.003131 -0.003149 -0.021826  0.058345
#
#                  LBDLYMNO   LBDMONO   LBDNENO   LBDEONO   LBDBANO  LBXRBCSI  \
# DepressionScore  0.024749  0.039166  0.093702  0.010203  0.031255 -0.078206
# LBXBCD           0.054873  0.078116  0.073871  0.059920  0.071271  0.054540
# LBDBCDSI         0.054877  0.078108  0.073879  0.059928  0.071277  0.054570
# LBXBPB          -0.025833  0.027674 -0.052466  0.011694 -0.008167  0.087274
# LBXWBCSI         0.621930  0.540508  0.810719  0.218615  0.331551 -0.010164
# LBDLYMNO         1.000000  0.357346  0.061086  0.100791  0.276679  0.046565
# LBDMONO          0.357346  1.000000  0.339708  0.202421  0.197272  0.028619
# LBDNENO          0.061086  0.339708  1.000000  0.102831  0.189859 -0.055598
# LBDEONO          0.100791  0.202421  0.102831  1.000000  0.140411  0.081637
# LBDBANO          0.276679  0.197272  0.189859  0.140411  1.000000 -0.019474
# LBXRBCSI         0.046565  0.028619 -0.055598  0.081637 -0.019474  1.000000
# LBXHGB           0.034290  0.057163 -0.039659  0.090703 -0.038051  0.759503
# LBXMCHSI        -0.020166  0.041161  0.021621  0.008246 -0.030619 -0.352425
# LBXRDW          -0.000134  0.036250  0.033045  0.009769  0.059069 -0.080151
# LBXPLTSI         0.117866  0.078929  0.205625  0.118717  0.123376 -0.006242
# LBXMPSI         -0.001059  0.021373  0.041059 -0.018533 -0.002560  0.071045
# LBXCRP           0.040880  0.158769  0.253412  0.050346  0.078758 -0.090501
# LBXVID          -0.041466  0.059388  0.102378 -0.001411 -0.011056 -0.065652
#
#                    LBXHGB  LBXMCHSI    LBXRDW  LBXPLTSI   LBXMPSI    LBXCRP  \
# DepressionScore -0.089145 -0.018395  0.118649  0.062647  0.000353  0.083865
# LBXBCD           0.140983  0.122018  0.084576  0.005530 -0.021277  0.012294
# LBDBCDSI         0.141013  0.122016  0.084538  0.005544 -0.021291  0.012298
# LBXBPB           0.128587  0.059423  0.115427 -0.101594  0.016290 -0.014597
# LBXWBCSI        -0.002784  0.008186  0.028080  0.232801  0.032040  0.226939
# LBDLYMNO         0.034290 -0.020166 -0.000134  0.117866 -0.001059  0.040880
# LBDMONO          0.057163  0.041161  0.036250  0.078929  0.021373  0.158769
# LBDNENO         -0.039659  0.021621  0.033045  0.205625  0.041059  0.253412
# LBDEONO          0.090703  0.008246  0.009769  0.118717 -0.018533  0.050346
# LBDBANO         -0.038051 -0.030619  0.059069  0.123376 -0.002560  0.078758
# LBXRBCSI         0.759503 -0.352425 -0.080151 -0.006242  0.071045 -0.090501
# LBXHGB           1.000000  0.333319 -0.386739 -0.134638  0.021117 -0.161950
# LBXMCHSI         0.333319  1.000000 -0.433881 -0.192630 -0.070997 -0.101450
# LBXRDW          -0.386739 -0.433881  1.000000  0.094689  0.033970  0.158203
# LBXPLTSI        -0.134638 -0.192630  0.094689  1.000000 -0.393341  0.162613
# LBXMPSI          0.021117 -0.070997  0.033970 -0.393341  1.000000 -0.031162
# LBXCRP          -0.161950 -0.101450  0.158203  0.162613 -0.031162  1.000000
# LBXVID           0.094728  0.230859 -0.171526 -0.050982 -0.079994 -0.048709
#
#                    LBXVID
# DepressionScore -0.066279
# LBXBCD          -0.003131
# LBDBCDSI        -0.003149
# LBXBPB          -0.021826
# LBXWBCSI         0.058345
# LBDLYMNO        -0.041466
# LBDMONO          0.059388
# LBDNENO          0.102378
# LBDEONO         -0.001411
# LBDBANO         -0.011056
# LBXRBCSI        -0.065652
# LBXHGB           0.094728
# LBXMCHSI         0.230859
# LBXRDW          -0.171526
# LBXPLTSI        -0.050982
# LBXMPSI         -0.079994
# LBXCRP          -0.048709
# LBXVID           1.000000

# %% [markdown]
# We do have some redundant columns in the data now. LBXBCD - Cadmium (ug/L) and LBDBCDSI Cadmium (nmol/L) both measured the same thing, hence the correlation of 1.00 between the two variables.
# Other redundancies include: LBXBPB and LBDBPBSI, LBXLYPCT and LBDLYMNO, LBXMOPCT and LBDMONO, LBXNEPCT and LBDNENO, LBXBAPCT and LBDBANO, LBXEOPCT and LBDEONO, LBXHGB and LBXHCT, LBXMCHSI and LBXMCVSI and LBXMC

# %%
to_drop = ["LBDBPBSI", "LBXLYPCT", "LBXMOPCT", "LBXNEPCT", "LBXBAPCT", "LBXEOPCT", "LBXHCT", "LBXMCVSI", "LBXMC"]
master.drop(to_drop, axis = 1, inplace = True)

# %% [markdown]
# ## Model Fitting

# %%
from sklearn.model_selection import train_test_split

trainX, testX, trainy, testy = train_test_split(master.dropna().drop("DepressionScore", axis = 1), master.dropna()["DepressionScore"], test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression().fit(trainX, trainy)
preds_lm = lm.predict(testX)
lm.score(trainX, trainy)
# Out:
# 0.05273780957104557

# %% [markdown]
# R^2 is 0.05 - linear model preforms very poorly. Either the linear model poorly measures a non-linear relationship or the predictors contain very little information about the mental health of our participants. Let's try a tree-based method:

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth = 2)
rf.fit(trainX, trainy)
preds_rf = rf.predict(testX)
rf.score(trainX, trainy)
# Out:
# 0.060034486182498625

# %% [markdown]
# R^2 is 0.06 - our coefficient of determination only improves slightly with a non-linear model. This would lead me to conclude that our predictors contain no information about the mental health of our participants.
